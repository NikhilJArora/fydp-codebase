# %% [markdown]
# # Parking-spot Dataset Prep:

# %% [markdown]
# List of raw images to be processed:
# Done:
# IMG_9767.JPG
# IMG_9823.JPG
# IMG_9827.JPG
# IMG_9831.JPG
# IMG_9835.JPG
# IMG_9839.JPG
# IMG_9768.JPG
# IMG_9824.JPG
# IMG_9828.JPG
# IMG_9832.JPG
# *IMG_9836.JPG*
# IMG_9840.JPG
# IMG_9769.JPG
# IMG_9825.JPG
# IMG_9829.JPG
# IMG_9833.JPG
# IMG_9837.JPG
# IMG_9841.JPG
# IMG_9822.JPG
# IMG_9826.JPG
# IMG_9830.JPG
# IMG_9834.JPG
# IMG_9838.JPG
# IMG_9842.JPG
#
# Not Done:
#
# **Need to collect more non-event data**

# %%
# imports
import os
import sys

import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import skimage 
from skimage import io, color, exposure

# %matplotlib inline

# %%
# consts
# image folder:
r_images_dir = '/Users/nikhilarora/data/fydp/sb_images/orig'


# output location:
data_car_dir = '/Users/nikhilarora/data/fydp/dataset/car'
data_ncar_dir = '/Users/nikhilarora/data/fydp/dataset/ncar'

# %%
# grab a photo
# ADD PHOTO NAME WITHIN WORKING DIR:
photo_name = 'IMG_9842.JPG' 
r_img = np.flip(np.flip(io.imread(os.path.join(r_images_dir, photo_name)),1),0)

# %%
# look at the photo in a grid 
plt.imshow(r_img,cmap='gray')

# %%
# define the starting and ending values for slicing each spot 
# (ystart, yend, xstart, xend)
spots = [
    (1600, 2300, 500, 1700),
    (1600, 2300, 2000, 3400),
    #(2000, 2500, 2600, 4000)
]

# %%
# slice the spot and output each image:
spot = spots[1]
ps_img = r_img[spot[0]:spot[1], spot[2]:spot[3]]
plt.imshow(ps_img, cmap='gray')

# %%
# if car place in /data/car/
# if no car, place in /data/ncar/
car = True

foutname = 'sp_{}.jpg'.format(str(np.random.randint(1000)))
print(foutname)
cln_car = os.path.join(data_car_dir, foutname)
cln_ncar = os.path.join(data_ncar_dir, foutname)

# write to file:
if car:
    io.imsave(cln_car,ps_img)
else:
    io.imsave(cln_ncar,ps_img)
# Out:
# sp_964.jpg
