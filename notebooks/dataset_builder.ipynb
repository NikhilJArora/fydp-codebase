# %% [markdown]
# # Parking-spot Dataset Prep:

# %% [markdown]
# List of raw images to be processed:
# Done:
# IMG_9767.JPG
# IMG_9823.JPG
# IMG_9827.JPG
# IMG_9831.JPG
# IMG_9835.JPG
# IMG_9839.JPG
# IMG_9768.JPG
# IMG_9824.JPG
# IMG_9828.JPG
# IMG_9832.JPG
# *IMG_9836.JPG*
# IMG_9840.JPG
# IMG_9769.JPG
# IMG_9825.JPG
# IMG_9829.JPG
# IMG_9833.JPG
# IMG_9837.JPG
# IMG_9841.JPG
# IMG_9822.JPG
# IMG_9826.JPG
# IMG_9830.JPG
# IMG_9834.JPG
# IMG_9838.JPG
# IMG_9842.JPG
#
# Not Done:
#
# **Need to collect more non-event data**

# %%
# imports
import os
import sys

import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import skimage 
from skimage import io, color, exposure

# %matplotlib inline

# %%
# consts
# image folder:
r_images_dir = '/Users/nikhilarora/data/fydp/sb_images/orig_od'


# output location:
data_car_dir = '/Users/nikhilarora/data/fydp/dataset/car_os'
data_ncar_dir = '/Users/nikhilarora/data/fydp/dataset/ncar_os'

# %%
# list all files in dir:
f_list = os.listdir(r_images_dir)
f_list = f_list[1:]
f_list
# Out:
# ['IMG_2139.JPG',
#  'IMG_2140.JPG',
#  'IMG_2142.JPG',
#  'IMG_2143.JPG',
#  'IMG_2144.JPG',
#  'IMG_2145.JPG',
#  'IMG_2146.JPG',
#  'IMG_2147.JPG',
#  'IMG_2148.JPG',
#  'IMG_2149.JPG',
#  'IMG_2150.JPG',
#  'IMG_2152.JPG',
#  'IMG_2153.JPG',
#  'IMG_2154.JPG',
#  'IMG_2155.JPG',
#  'IMG_2156.JPG',
#  'IMG_2157.JPG',
#  'IMG_2158.JPG',
#  'IMG_2159.JPG',
#  'IMG_2160.JPG',
#  'IMG_2161.JPG',
#  'IMG_2162.JPG',
#  'IMG_2163.JPG',
#  'IMG_2164.JPG',
#  'IMG_2165.JPG']

# %%
# grab a photo
# ADD PHOTO NAME WITHIN WORKING DIR:
photo_name = 'IMG_2155.JPG'
# r_img = np.flip(np.flip(io.imread(os.path.join(r_images_dir, photo_name)),1),0)
r_img = io.imread(os.path.join(r_images_dir, photo_name))

# %%
# look at the photo in a grid 
plt.imshow(r_img,cmap='gray')

# %%
# define the starting and ending values for slicing each spot 
# (ystart, yend, xstart, xend)
spots = [
    (1100, 1600, 250, 1100),
    (1100, 1600, 1200, 2000),
    (1100, 1600, 2250, 3200)
]

# %%
# slice the spot and output each image:
spot = spots[1]
ps_img = r_img[spot[0]:spot[1], spot[2]:spot[3]]
plt.imshow(ps_img, cmap='gray')

# %%
# if car place in /data/car/
# if no car, place in /data/ncar/
car = False

foutname = 'sp_{}.jpg'.format(str(np.random.randint(1000)))
print(foutname)
cln_car = os.path.join(data_car_dir, foutname)
cln_ncar = os.path.join(data_ncar_dir, foutname)

# write to file:
if car:
    print("car")
    io.imsave(cln_car,ps_img)
else:
    print("not car")
    io.imsave(cln_ncar,ps_img)
# Out:
# sp_328.jpg
# not car
